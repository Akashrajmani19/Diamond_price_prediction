# %%
import logging
import os
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 11, 4, 10, 48, 1, 727073)

# %%
f"{datetime.now().strftime('%d_%m_%Y_%H_%M_%S')}.log"
# Out:
# '04_11_2023_10_48_01.log'

# %%
os.path.join(os.getcwd(),'logs')
# Out:
# 'f:\\Project_template\\notebooks\\logs'

# %%
from src.Diamond_price_prediction.logger import logging

# %%
logging.info("I have just teasted the things")

# %%
from dataclasses import dataclass
from pathlib import Path
